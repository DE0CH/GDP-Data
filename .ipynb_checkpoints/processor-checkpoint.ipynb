# %%
import re
import numpy as np
from math import sqrt

# %%
tide_heights = []

# %%
with open("2021LEI.txt") as f:
    for line in f:
        if line.strip():
            l = line.split()
            h = float(re.sub("[A-Z]", "", l[3]))
            tide_heights.append(float(re.sub("[A-Z]", "", l[3])))

# %% [markdown]
#  25359) 2021/09/22 03:30:00 is changed to the average of the before and after because this is clearly an outlier

# %%
start, end = 1000, 2500

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(18, 16))

plt.plot(np.arange(start, end), tide_heights[start:end])

# %%
t = 15 * 60

# %%
efficiency = 0.9

# %%
rho_water = 997

# %%
gravity_earth = 9.8

# %%
out_max_efficienty = 16/27

# %%
energy_need_total = 7.14E8 * 1000 * 3600

# %%
average_power_needed = energy_need_total / 31536000

# %%
average_power_needed
# Out:
# 81506849.3150685

# %%
size_of_lagoon = 1E9

# %%
level = [0] * (len(tide_heights) + 1)

# %%
lack = [0] * len(tide_heights)

# %%
energy_needed = [0] * len(tide_heights)

# %%
energy_needed_0 = [average_power_needed * t] * len(tide_heights)

# %%
for i in range(len(tide_heights)):
    if energy_needed[i] >= 0:
        energy_needed[i] = energy_needed_0[i] / efficiency / out_max_efficienty
        max_potential = (level[i] - tide_heights[i])**2 / 2 * size_of_lagoon * rho_water *  gravity_earth
        height_diff = abs(level[i] - tide_heights[i])
        if max_potential >= energy_needed[i]:
            change = height_diff - sqrt(height_diff**2 - 2*energy_needed[i] / (size_of_lagoon * rho_water * gravity_earth))
        if max_potential >= energy_needed[i] and level[i] > tide_heights[i]:
            level[i+1] = level[i] - change
        elif max_potential >= energy_needed[i]:
            level[i+1] = level[i] + change
        else:
            level[i+1] = tide_heights[i]
            lack[i] = energy_needed[i] - max_potential
    else:
        pass # TODO: excess of energy

# %%
plt.figure(figsize=(18, 16))
plt.plot(np.arange(start, end), level[start:end])

# %%
plt.figure(figsize=(18, 16))
plt.plot(np.arange(start, end), lack[start:end])

# %%
plt.figure(figsize=(18, 16))
plt.plot(np.arange(start, end), tide_heights[start:end])
plt.plot(np.arange(start, end), level[start:end])
